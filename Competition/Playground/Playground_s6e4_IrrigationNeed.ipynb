# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonanda1013/DataLoverz/blob/main/Competition/Playground/Playground_s6e4_IrrigationNeed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_train = pd.read_csv('/content/drive/MyDrive/DATASET/playground-series-s6e4/train.csv')

# %%
df_train.head()
# Out:
#    id Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0   0     Loamy     4.92          32.58            1.01
# 1   1      Clay     7.08          56.61            0.44
# 2   2      Clay     5.69          27.71            0.81
# 3   3     Sandy     5.65          13.32            1.33
# 4   4      Clay     7.96          59.14            0.38
#
#    Electrical_Conductivity  Temperature_C  Humidity  Rainfall_mm  \
# 0                     3.05          15.01     50.61       725.99
# 1                     2.00          22.92     67.86       985.66
# 2                     2.83          26.97     92.22      2201.70
# 3                     0.87          13.32     61.57      1357.33
# 4                     0.96          20.22     91.11      1538.20
#
#    Sunlight_Hours  ...  Crop_Type Crop_Growth_Stage  Season Irrigation_Type  \
# 0            5.90  ...  Sugarcane            Sowing    Zaid            Drip
# 1            6.98  ...      Wheat        Vegetative  Kharif         Rainfed
# ...

# %%
df_train.tail()
# Out:
#             id Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  \
# 629995  629995      Clay     6.54          13.45            1.15
# 629996  629996      Clay     7.03          54.49            0.96
# 629997  629997      Clay     6.52          11.98            0.93
# 629998  629998      Clay     5.93          42.86            0.33
# 629999  629999     Loamy     7.02          35.36            1.19
#
#         Electrical_Conductivity  Temperature_C  Humidity  Rainfall_mm  \
# 629995                     1.86          26.65     26.86      1041.33
# 629996                     2.35          36.99     88.00      1419.57
# 629997                     0.38          37.82     70.98        88.45
# 629998                     3.39          34.99     94.58      2433.92
# 629999                     0.46          26.92     64.33      1269.55
#
#         Sunlight_Hours  ...  Crop_Type Crop_Growth_Stage  Season  \
# 629995           10.62  ...       Rice            Sowing  Kharif
# ...

# %%
df_train
# Out:
#             id Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0            0     Loamy     4.92          32.58            1.01
# 1            1      Clay     7.08          56.61            0.44
# 2            2      Clay     5.69          27.71            0.81
# 3            3     Sandy     5.65          13.32            1.33
# 4            4      Clay     7.96          59.14            0.38
# ...        ...       ...      ...            ...             ...
# 629995  629995      Clay     6.54          13.45            1.15
# 629996  629996      Clay     7.03          54.49            0.96
# 629997  629997      Clay     6.52          11.98            0.93
# 629998  629998      Clay     5.93          42.86            0.33
# 629999  629999     Loamy     7.02          35.36            1.19
#
#         Electrical_Conductivity  Temperature_C  Humidity  Rainfall_mm  \
# 0                          3.05          15.01     50.61       725.99
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630000 entries, 0 to 629999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       630000 non-null  int64
#  1   Soil_Type                630000 non-null  object
#  2   Soil_pH                  630000 non-null  float64
#  3   Soil_Moisture            630000 non-null  float64
#  4   Organic_Carbon           630000 non-null  float64
#  5   Electrical_Conductivity  630000 non-null  float64
#  6   Temperature_C            630000 non-null  float64
#  7   Humidity                 630000 non-null  float64
#  8   Rainfall_mm              630000 non-null  float64
#  9   Sunlight_Hours           630000 non-null  float64
#  10  Wind_Speed_kmh           630000 non-null  float64
#  11  Crop_Type                630000 non-null  object
#  12  Crop_Growth_Stage        630000 non-null  object
# ...

# %%
df_train.describe()
# Out:
#                   id        Soil_pH  Soil_Moisture  Organic_Carbon  \
# count  630000.000000  630000.000000  630000.000000   630000.000000
# mean   314999.500000       6.482497      37.304482        0.922858
# std    181865.479132       0.922504      16.377082        0.365808
# min         0.000000       4.800000       8.000000        0.300000
# 25%    157499.750000       5.690000      23.340000        0.610000
# 50%    314999.500000       6.440000      37.750000        0.910000
# 75%    472499.250000       7.270000      51.270000        1.220000
# max    629999.000000       8.200000      64.990000        1.600000
#
#        Electrical_Conductivity  Temperature_C       Humidity    Rainfall_mm  \
# count            630000.000000  630000.000000  630000.000000  630000.000000
# mean                  1.744605      26.998166      61.563180    1462.207566
# std                   0.952321       8.623621      19.708152     612.989738
# ...

# %%
df_train.select_dtypes(include=['object']).columns
# Out:
# Index(['Soil_Type', 'Crop_Type', 'Crop_Growth_Stage', 'Season',
#        'Irrigation_Type', 'Water_Source', 'Mulching_Used', 'Region',
#        'Irrigation_Need'],
#       dtype='object')

# %%
df_test.select_dtypes(include=['object']).columns
# Out:
# Index(['Soil_Type', 'Crop_Type', 'Crop_Growth_Stage', 'Season',
#        'Irrigation_Type', 'Water_Source', 'Mulching_Used', 'Region'],
#       dtype='object')

# %%
df_ordinal = df_train[['Soil_Type', 'Crop_Type', 'Crop_Growth_Stage', 'Season',
       'Irrigation_Type', 'Water_Source', 'Mulching_Used', 'Region',
       'Irrigation_Need']]

# %%
df_ordinal
# Out:
#        Soil_Type  Crop_Type Crop_Growth_Stage  Season Irrigation_Type  \
# 0          Loamy  Sugarcane            Sowing    Zaid            Drip
# 1           Clay      Wheat        Vegetative  Kharif         Rainfed
# 2           Clay       Rice        Vegetative  Kharif       Sprinkler
# 3          Sandy      Wheat         Flowering  Kharif           Canal
# 4           Clay      Wheat            Sowing    Rabi           Canal
# ...          ...        ...               ...     ...             ...
# 629995      Clay       Rice            Sowing  Kharif       Sprinkler
# 629996      Clay  Sugarcane        Vegetative  Kharif            Drip
# 629997      Clay     Potato        Vegetative    Zaid           Canal
# 629998      Clay  Sugarcane        Vegetative    Zaid       Sprinkler
# 629999     Loamy      Maize           Harvest  Kharif            Drip
#
#        Water_Source Mulching_Used   Region Irrigation_Need
# 0         Rainwater            No     East             Low
# ...

# %%
for col in df_ordinal.columns:
    print(f"Kolom: {col}")
    print(df_ordinal[[col]].value_counts())
    print("-"*50)
# Out:
# Kolom: Soil_Type
# Soil_Type
# Sandy        166509
# Clay         158470
# Loamy        156455
# Silt         148566
# Name: count, dtype: int64
# --------------------------------------------------
# Kolom: Crop_Type
# Crop_Type
# Sugarcane    108910
# Rice         106697
# Cotton       104645
# Maize        104274
# Wheat        103005
# Potato       102469
# Name: count, dtype: int64
# --------------------------------------------------
# Kolom: Crop_Growth_Stage
# Crop_Growth_Stage
# Harvest              167689
# Flowering            157563
# Vegetative           157246
# Sowing               147502
# Name: count, dtype: int64
# --------------------------------------------------
# Kolom: Season
# Season
# Kharif    216561
# Rabi      208033
# Zaid      205406
# Name: count, dtype: int64
# --------------------------------------------------
# Kolom: Irrigation_Type
# Irrigation_Type
# Canal              161901
# Sprinkler          161400
# Rainfed            155607
# ...

# %%
df_ordinal = df_train[['Mulching_Used','Irrigation_Need']]

# %%
df_ordinal
# Out:
#        Mulching_Used Irrigation_Need
# 0                 No             Low
# 1                Yes             Low
# 2                Yes             Low
# 3                Yes          Medium
# 4                 No             Low
# ...              ...             ...
# 629995            No          Medium
# 629996           Yes          Medium
# 629997           Yes            High
# 629998           Yes             Low
# 629999            No             Low
#
# [630000 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df_train['Mulching_Used'] = le.fit_transform(df_train['Mulching_Used'])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df_test['Mulching_Used'] = le.fit_transform(df_test['Mulching_Used'])

# %%
df_train
# Out:
#             id Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0            0     Loamy     4.92          32.58            1.01
# 1            1      Clay     7.08          56.61            0.44
# 2            2      Clay     5.69          27.71            0.81
# 3            3     Sandy     5.65          13.32            1.33
# 4            4      Clay     7.96          59.14            0.38
# ...        ...       ...      ...            ...             ...
# 629995  629995      Clay     6.54          13.45            1.15
# 629996  629996      Clay     7.03          54.49            0.96
# 629997  629997      Clay     6.52          11.98            0.93
# 629998  629998      Clay     5.93          42.86            0.33
# 629999  629999     Loamy     7.02          35.36            1.19
#
#         Electrical_Conductivity  Temperature_C  Humidity  Rainfall_mm  \
# 0                          3.05          15.01     50.61       725.99
# ...

# %%
mapping = {
    'Low': 0,
    'Medium': 1,
    'High': 2
}

df_train['Irrigation_Need'] = df_train['Irrigation_Need'].map(mapping)

# %%
mapping = {
    'Low': 0,
    'Medium': 1,
    'High': 2
}

df_test['Irrigation_Need'] = df_test['Irrigation_Need'].map(mapping)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Irrigation_Need'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_12815/3564323674.py in <cell line: 0>()
#       5 }
#       6
# ...

# %%
df_train
# Out:
#             id Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0            0     Loamy     4.92          32.58            1.01
# 1            1      Clay     7.08          56.61            0.44
# 2            2      Clay     5.69          27.71            0.81
# 3            3     Sandy     5.65          13.32            1.33
# 4            4      Clay     7.96          59.14            0.38
# ...        ...       ...      ...            ...             ...
# 629995  629995      Clay     6.54          13.45            1.15
# 629996  629996      Clay     7.03          54.49            0.96
# 629997  629997      Clay     6.52          11.98            0.93
# 629998  629998      Clay     5.93          42.86            0.33
# 629999  629999     Loamy     7.02          35.36            1.19
#
#         Electrical_Conductivity  Temperature_C  Humidity  Rainfall_mm  \
# 0                          3.05          15.01     50.61       725.99
# ...

# %%
df_train.select_dtypes(include=['object']).columns
# Out:
# Index(['Soil_Type', 'Crop_Type', 'Crop_Growth_Stage', 'Season',
#        'Irrigation_Type', 'Water_Source', 'Region'],
#       dtype='object')

# %%
cols = ['Soil_Type', 'Crop_Type', 'Crop_Growth_Stage', 'Season',
       'Irrigation_Type', 'Water_Source', 'Region']
df_train = pd.get_dummies(df_train, columns=cols, drop_first=True, dtype = int)

# %%
cols = ['Soil_Type', 'Crop_Type', 'Crop_Growth_Stage', 'Season',
       'Irrigation_Type', 'Water_Source', 'Region']
df_test = pd.get_dummies(df_test, columns=cols, drop_first=True, dtype = int)

# %%
df_train.head()
# Out:
#    id  Soil_pH  Soil_Moisture  Organic_Carbon  Electrical_Conductivity  \
# 0   0     4.92          32.58            1.01                     3.05
# 1   1     7.08          56.61            0.44                     2.00
# 2   2     5.69          27.71            0.81                     2.83
# 3   3     5.65          13.32            1.33                     0.87
# 4   4     7.96          59.14            0.38                     0.96
#
#    Temperature_C  Humidity  Rainfall_mm  Sunlight_Hours  Wind_Speed_kmh  ...  \
# 0          15.01     50.61       725.99            5.90           16.79  ...
# 1          22.92     67.86       985.66            6.98            3.39  ...
# 2          26.97     92.22      2201.70            6.05            3.85  ...
# 3          13.32     61.57      1357.33            9.12            2.31  ...
# 4          20.22     91.11      1538.20            6.95           13.94  ...
#
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630000 entries, 0 to 629999
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   id                            630000 non-null  int64
#  1   Soil_pH                       630000 non-null  float64
#  2   Soil_Moisture                 630000 non-null  float64
#  3   Organic_Carbon                630000 non-null  float64
#  4   Electrical_Conductivity       630000 non-null  float64
#  5   Temperature_C                 630000 non-null  float64
#  6   Humidity                      630000 non-null  float64
#  7   Rainfall_mm                   630000 non-null  float64
#  8   Sunlight_Hours                630000 non-null  float64
#  9   Wind_Speed_kmh                630000 non-null  float64
#  10  Field_Area_hectare            630000 non-null  float64
#  11  Mulching_Used                 630000 non-null  int64
# ...

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

from xgboost import XGBClassifier

# %%
X = df_train.drop(columns=['Irrigation_Need'])  # ganti 'target' sesuai punyamu
y = df_train['Irrigation_Need']

# %%
num_cols = X.select_dtypes(include='number').columns
cat_cols = X.select_dtypes(exclude='number').columns

# %%
numeric_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median'))
])

categorical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# %%
preprocessor = ColumnTransformer([
    ('num', numeric_pipeline, num_cols),
    ('cat', categorical_pipeline, cat_cols)
])

# %%
model = XGBClassifier(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    eval_metric='logloss'
)

# %%
pipeline = Pipeline([
    ('preprocessing', preprocessor),
    ('model', model)
])

# %%
pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   Index(['id', 'Soil_pH', 'Soil_Moisture', 'Organic_Carbon',
#        'Electrical_Conductivity', 'Temperature_C', 'Humidity', 'Rainfall_mm',
#        'Sunlight_Hours', 'Wind_Speed_kmh', 'Field_Area_hectare',
#        'Mulching_Used', 'Previous_Irrigation_m...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.05,
#                                max_bin=None, max_cat_threshold=None,
# ...

# %%
df_test = pd.read_csv('/content/drive/MyDrive/DATASET/playground-series-s6e4/test.csv')

# %%
preds = pipeline.predict(df_test)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270000 entries, 0 to 269999
# Data columns (total 36 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   id                            270000 non-null  int64
#  1   Soil_pH                       270000 non-null  float64
#  2   Soil_Moisture                 270000 non-null  float64
#  3   Organic_Carbon                270000 non-null  float64
#  4   Electrical_Conductivity       270000 non-null  float64
#  5   Temperature_C                 270000 non-null  float64
#  6   Humidity                      270000 non-null  float64
#  7   Rainfall_mm                   270000 non-null  float64
#  8   Sunlight_Hours                270000 non-null  float64
#  9   Wind_Speed_kmh                270000 non-null  float64
#  10  Field_Area_hectare            270000 non-null  float64
#  11  Mulching_Used                 270000 non-null  int64
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630000 entries, 0 to 629999
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   id                            630000 non-null  int64
#  1   Soil_pH                       630000 non-null  float64
#  2   Soil_Moisture                 630000 non-null  float64
#  3   Organic_Carbon                630000 non-null  float64
#  4   Electrical_Conductivity       630000 non-null  float64
#  5   Temperature_C                 630000 non-null  float64
#  6   Humidity                      630000 non-null  float64
#  7   Rainfall_mm                   630000 non-null  float64
#  8   Sunlight_Hours                630000 non-null  float64
#  9   Wind_Speed_kmh                630000 non-null  float64
#  10  Field_Area_hectare            630000 non-null  float64
#  11  Mulching_Used                 630000 non-null  int64
# ...

# %%
preds
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
df_submit = pd.DataFrame({
    'id': df_test['id'],   # pastikan nama kolom sesuai (Id / id)
    'Irrigation_Need': preds        # hasil prediksi model
})

# %%
df_submit
# Out:
#             id  Irrigation_Need
# 0       630000                0
# 1       630001                0
# 2       630002                0
# 3       630003                0
# 4       630004                0
# ...        ...              ...
# 269995  899995                1
# 269996  899996                0
# 269997  899997                1
# 269998  899998                0
# 269999  899999                1
#
# [270000 rows x 2 columns]

# %%
df_submit.to_csv('submission.csv', index=False)

# %%
reverse_mapping = {
    0: 'Low',
    1: 'Medium',
    2: 'High'
}

df_submit['Irrigation_Need'] = df_submit['Irrigation_Need'].map(reverse_mapping)

# %%
pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 7.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# %%
X = df_train.drop(columns=['Irrigation_Need'])  # ganti sesuai target kamu
y = df_train['Irrigation_Need']

# %%
num_cols = X.select_dtypes(include='number').columns
cat_cols = X.select_dtypes(exclude='number').columns

# %%
numeric_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median'))
])

categorical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer([
    ('num', numeric_pipeline, num_cols),
    ('cat', categorical_pipeline, cat_cols)
])

# %%
models = {
    "RandomForest": RandomForestClassifier(
        n_estimators=200,
        random_state=42
    ),

    "XGBoost": XGBClassifier(
        n_estimators=300,
        learning_rate=0.05,
        max_depth=6,
        subsample=0.8,
        colsample_bytree=0.8,
        eval_metric='logloss',
        random_state=42
    ),

    "LightGBM": LGBMClassifier(
        n_estimators=300,
        learning_rate=0.05,
        random_state=42
    ),

    "CatBoost": CatBoostClassifier(
        iterations=300,
        learning_rate=0.05,
        depth=6,
        verbose=0,
        random_state=42
    )
}

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

results = {}

for name, model in models.items():

    pipeline = Pipeline([
        ('preprocessing', preprocessor),
        ('model', model)
    ])

    scores = cross_val_score(
        pipeline,
        X,
        y,
        cv=kfold,
        scoring='accuracy',  # bisa diganti roc_auc / f1
        n_jobs=-1
    )

    results[name] = scores

    print(f"{name}")
    print(f"Mean Accuracy: {scores.mean():.4f}")
    print(f"Std: {scores.std():.4f}")
    print("-"*40)
# Out:
# /usr/local/lib/python3.12/dist-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# RandomForest
# Mean Accuracy: 0.9851
# Std: 0.0002
# ----------------------------------------
# XGBoost
# Mean Accuracy: 0.9844
# Std: 0.0003
# ----------------------------------------
# LightGBM
# Mean Accuracy: 0.9843
# Std: 0.0001
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# CatBoost
# Mean Accuracy: 0.9845
# Std: 0.0005
# ----------------------------------------

# %%
result_df = pd.DataFrame(results)
print(result_df.describe().T)
# Out:
#               count      mean       std       min       25%       50%  \
# RandomForest    5.0  0.985129  0.000264  0.984833  0.985016  0.985087
# XGBoost         5.0  0.984443  0.000319  0.984008  0.984270  0.984437
# LightGBM        5.0  0.984257  0.000166  0.984087  0.984111  0.984270
# CatBoost        5.0  0.984494  0.000571  0.983603  0.984341  0.984603
#
#                    75%       max
# RandomForest  0.985159  0.985548
# XGBoost       0.984738  0.984762
# LightGBM      0.984325  0.984492
# CatBoost      0.984817  0.985103

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.pipeline import Pipeline

voting_model = VotingClassifier(
    estimators=[
        ('rf', models['RandomForest']),
        ('xgb', models['XGBoost']),
        ('lgbm', models['LightGBM']),
        ('cat', models['CatBoost'])
    ],
    voting='soft'  # pakai probabilitas (lebih bagus)
)

pipeline_voting = Pipeline([
    ('preprocessing', preprocessor),
    ('model', voting_model)
])

# %%
pipeline_voting.fit(X, y)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.042088 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2972
# [LightGBM] [Info] Number of data points in the train set: 630000, number of used features: 36
# [LightGBM] [Info] Start training from score -0.532441
# [LightGBM] [Info] Start training from score -0.968947
# [LightGBM] [Info] Start training from score -3.400769
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   Index(['id', 'Soil_pH', 'Soil_Moisture', 'Organic_Carbon',
# ...

# %%
preds = pipeline_voting.predict(df_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %%
df_submit = pd.DataFrame({
    'id': df_test['id'],   # pastikan nama kolom sesuai (Id / id)
    'Irrigation_Need': preds        # hasil prediksi model
})

# %%
reverse_mapping = {
    0: 'Low',
    1: 'Medium',
    2: 'High'
}

df_submit['Irrigation_Need'] = df_submit['Irrigation_Need'].map(reverse_mapping)

# %%
df_submit.to_csv('submission_ensemble.csv', index=False)
