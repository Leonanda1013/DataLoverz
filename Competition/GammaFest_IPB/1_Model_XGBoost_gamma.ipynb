# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonanda1013/DataLoverz/blob/main/Competition/GammaFest_IPB/1_Model_XGBoost_gamma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.multioutput import MultiOutputClassifier

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.multioutput import MultiOutputRegressor
from xgboost import XGBRegressor

# %%
df_train = pd.read_csv('train_clean.csv')
df_test = pd.read_csv('test_clean.csv')

# %%
train = df_train.copy()
test = df_test.copy()

# simpan id
test_id = test['Id']

# drop id
train = train.drop(columns=['id'], errors='ignore')
test = test.drop(columns=['id'], errors='ignore')

# %%
target_cols = ['team_goals', 'opp_goals']

X = train.drop(columns=target_cols)
y = train[target_cols]

# %%
cat_cols = X.select_dtypes(include=['object', 'category']).columns
num_cols = X.select_dtypes(include=['int64', 'float64']).columns

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', 'passthrough', num_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_cols)
    ]
)

# %%
base_model = XGBRegressor(
    n_estimators=500,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    tree_method='hist'
)

model = MultiOutputRegressor(base_model)

# %%
pipeline = Pipeline(steps=[
    ('preprocessing', preprocessor),
    ('model', model)
])

# %%
pipeline.fit(X, y)

# %%
preds = pipeline.predict(test)

# hasilnya array shape (n_samples, 2)

# %%
submission = pd.DataFrame({
    'id': test_id,
    'team_goals': preds[:, 0],
    'opp_goals': preds[:, 1]
})

submission.head()

# %%
import numpy as np

preds_rounded = np.round(preds)

# %%
submission = pd.DataFrame({
    'Id': test_id,
    'team_goals': np.round(preds[:, 0]),
    'opp_goals': np.round(preds[:, 1])
})

# %%
submission.head()

# %%
submission.to_csv('submission_gmc.csv', index=False)
