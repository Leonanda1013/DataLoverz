# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonanda1013/DataLoverz/blob/main/Matplotlib/Matplotlip_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Membuat Data
# 2. Membuat Plot
# 3. Menampilkan Plot

# %%
# 1. Membuat Data
x = np.array([1,2,3,4,5])
y = np.array([1,4,9,16,25])
y2 = np.array([1,16,81,256,625])

# %%
# 2. Membuat Plot
plt.plot(x,y)
plt.plot(x,y2)

# 3. Menampilkan Plot
plt.show()
